# %%
import json
import numpy as np
from sklearn.model_selection import train_test_split
import tensorflow.keras as keras

# %%
DATA_PATH = "data_10.json"

# %%
def load_data(data_path):
    """Loads training dataset from json file.
        :param data_path (str): Path to json file containing data
        :return X (ndarray): Inputs
        :return y (ndarray): Targets
    """

    with open(data_path, "r") as fp:
        data = json.load(fp)

    # convert lists to numpy arrays
    X = np.array(data["mfcc"])
    y = np.array(data["labels"])

    print("Data succesfully loaded!")

    return  X, y


if __name__ == "__main__":

    # load data
    X, y = load_data(DATA_PATH)

    # create train/test split
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

    # build network topology
    model = keras.Sequential([

        # input layer
        keras.layers.Flatten(input_shape=(X.shape[1], X.shape[2])),

        # 1st dense layer
        keras.layers.Dense(512, activation='relu'),

        # 2nd dense layer
        keras.layers.Dense(256, activation='relu'),

        # 3rd dense layer
        keras.layers.Dense(64, activation='relu'),

        # output layer
        keras.layers.Dense(10, activation='softmax')
    ])

    # compile model
    optimiser = keras.optimizers.Adam(learning_rate=0.0001)
    model.compile(optimizer=optimiser,
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])

    model.summary()

    # train model
    history = model.fit(X_train, y_train, validation_data=(X_test, y_test), batch_size=32, epochs=50)
# Out:
# Data succesfully loaded!
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten (Flatten)           (None, 1690)              0
#
#  dense (Dense)               (None, 512)               865792
#
#  dense_1 (Dense)             (None, 256)               131328
#
#  dense_2 (Dense)             (None, 64)                16448
#
#  dense_3 (Dense)             (None, 10)                650
#
# =================================================================
# Total params: 1,014,218
# Trainable params: 1,014,218
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 219/219 [==============================] - 4s 14ms/step - loss: 9.1410 - accuracy: 0.3334 - val_loss: 5.3278 - val_accuracy: 0.3731
# Epoch 2/50
# 219/219 [==============================] - 3s 12ms/step - loss: 3.8835 - accuracy: 0.4375 - val_loss: 3.8966 - val_accuracy: 0.4031
# Epoch 3/50
# 219/219 [==============================] - 2s 11ms/step - loss: 2.7478 - accuracy: 0.4951 - val_loss: 3.3146 - val_accuracy: 0.4375
# Epoch 4/50
# 219/219 [==============================] - 2s 10ms/step - loss: 1.9905 - accuracy: 0.5604 - val_loss: 3.0473 - val_accuracy: 0.4328
# Epoch 5/50
# 219/219 [==============================] - 2s 10ms/step - loss: 1.5850 - accuracy: 0.6084 - val_loss: 2.9015 - val_accuracy: 0.4585
# Epoch 6/50
# 219/219 [==============================] - 2s 10ms/step - loss: 1.2762 - accuracy: 0.6559 - val_loss: 2.9353 - val_accuracy: 0.4685
# Epoch 7/50
# 219/219 [==============================] - 2s 11ms/step - loss: 1.0973 - accuracy: 0.6933 - val_loss: 2.8464 - val_accuracy: 0.4685
# Epoch 8/50
# 219/219 [==============================] - 2s 11ms/step - loss: 0.9178 - accuracy: 0.7367 - val_loss: 2.6746 - val_accuracy: 0.4932
# Epoch 9/50
# 219/219 [==============================] - 2s 11ms/step - loss: 0.8078 - accuracy: 0.7628 - val_loss: 2.5658 - val_accuracy: 0.5042
# Epoch 10/50
# 219/219 [==============================] - 3s 11ms/step - loss: 0.7105 - accuracy: 0.7851 - val_loss: 2.4141 - val_accuracy: 0.5088
# Epoch 11/50
# 219/219 [==============================] - 2s 10ms/step - loss: 0.5945 - accuracy: 0.8153 - val_loss: 2.5470 - val_accuracy: 0.5072
# Epoch 12/50
# 219/219 [==============================] - 2s 10ms/step - loss: 0.4739 - accuracy: 0.8484 - val_loss: 2.5798 - val_accuracy: 0.5215
# Epoch 13/50
# 219/219 [==============================] - 2s 11ms/step - loss: 0.4711 - accuracy: 0.8472 - val_loss: 2.4381 - val_accuracy: 0.5378
# Epoch 14/50
# 219/219 [==============================] - 2s 11ms/step - loss: 0.3712 - accuracy: 0.8850 - val_loss: 2.5121 - val_accuracy: 0.5288
# Epoch 15/50
# 219/219 [==============================] - 2s 11ms/step - loss: 0.3448 - accuracy: 0.8914 - val_loss: 2.4103 - val_accuracy: 0.5412
# Epoch 16/50
# 219/219 [==============================] - 2s 11ms/step - loss: 0.2384 - accuracy: 0.9188 - val_loss: 2.3827 - val_accuracy: 0.5512
# Epoch 17/50
# 219/219 [==============================] - 2s 11ms/step - loss: 0.2341 - accuracy: 0.9223 - val_loss: 2.5725 - val_accuracy: 0.5375
# Epoch 18/50
# 219/219 [==============================] - 2s 11ms/step - loss: 0.2712 - accuracy: 0.9110 - val_loss: 2.6233 - val_accuracy: 0.5458
# Epoch 19/50
# 219/219 [==============================] - 2s 10ms/step - loss: 0.2272 - accuracy: 0.9250 - val_loss: 2.5327 - val_accuracy: 0.5519
# Epoch 20/50
# 219/219 [==============================] - 2s 10ms/step - loss: 0.1972 - accuracy: 0.9374 - val_loss: 2.6442 - val_accuracy: 0.5519
# Epoch 21/50
# 219/219 [==============================] - 2s 11ms/step - loss: 0.1929 - accuracy: 0.9361 - val_loss: 2.5208 - val_accuracy: 0.5639
# Epoch 22/50
# 219/219 [==============================] - 2s 11ms/step - loss: 0.1451 - accuracy: 0.9547 - val_loss: 2.8070 - val_accuracy: 0.5562
# Epoch 23/50
# 219/219 [==============================] - 2s 11ms/step - loss: 0.2786 - accuracy: 0.9092 - val_loss: 2.7783 - val_accuracy: 0.5405
# Epoch 24/50
# 219/219 [==============================] - 2s 11ms/step - loss: 0.3138 - accuracy: 0.9005 - val_loss: 2.6470 - val_accuracy: 0.5465
# Epoch 25/50
# 219/219 [==============================] - 2s 10ms/step - loss: 0.1605 - accuracy: 0.9458 - val_loss: 2.6792 - val_accuracy: 0.5525
# Epoch 26/50
# 219/219 [==============================] - 2s 10ms/step - loss: 0.1727 - accuracy: 0.9461 - val_loss: 2.7480 - val_accuracy: 0.5679
# Epoch 27/50
# 219/219 [==============================] - 2s 11ms/step - loss: 0.2172 - accuracy: 0.9318 - val_loss: 2.7802 - val_accuracy: 0.5482
# Epoch 28/50
# 219/219 [==============================] - 3s 12ms/step - loss: 0.2014 - accuracy: 0.9333 - val_loss: 2.5462 - val_accuracy: 0.5815
# Epoch 29/50
# 219/219 [==============================] - 2s 11ms/step - loss: 0.1095 - accuracy: 0.9630 - val_loss: 2.6160 - val_accuracy: 0.5772
# Epoch 30/50
# 219/219 [==============================] - 2s 11ms/step - loss: 0.1245 - accuracy: 0.9600 - val_loss: 2.8119 - val_accuracy: 0.5629
# Epoch 31/50
# 219/219 [==============================] - 2s 11ms/step - loss: 0.1494 - accuracy: 0.9526 - val_loss: 2.8632 - val_accuracy: 0.5542
# Epoch 32/50
# 219/219 [==============================] - 2s 11ms/step - loss: 0.2158 - accuracy: 0.9324 - val_loss: 2.9345 - val_accuracy: 0.5565
# Epoch 33/50
# 219/219 [==============================] - 3s 12ms/step - loss: 0.1908 - accuracy: 0.9340 - val_loss: 2.8534 - val_accuracy: 0.5679
# Epoch 34/50
# 219/219 [==============================] - 3s 12ms/step - loss: 0.0955 - accuracy: 0.9688 - val_loss: 2.8041 - val_accuracy: 0.5869
# Epoch 35/50
# 219/219 [==============================] - 3s 12ms/step - loss: 0.1096 - accuracy: 0.9681 - val_loss: 3.0303 - val_accuracy: 0.5655
# Epoch 36/50
# 219/219 [==============================] - 3s 12ms/step - loss: 0.1546 - accuracy: 0.9494 - val_loss: 2.8521 - val_accuracy: 0.5639
# Epoch 37/50
# 219/219 [==============================] - 2s 11ms/step - loss: 0.1376 - accuracy: 0.9574 - val_loss: 2.9480 - val_accuracy: 0.5835
# Epoch 38/50
# 219/219 [==============================] - 2s 10ms/step - loss: 0.1323 - accuracy: 0.9557 - val_loss: 2.7974 - val_accuracy: 0.5892
# Epoch 39/50
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0745 - accuracy: 0.9758 - val_loss: 2.9291 - val_accuracy: 0.5839
# Epoch 40/50
# 219/219 [==============================] - 2s 11ms/step - loss: 0.1121 - accuracy: 0.9643 - val_loss: 2.8029 - val_accuracy: 0.5745
# Epoch 41/50
# 219/219 [==============================] - 2s 11ms/step - loss: 0.1251 - accuracy: 0.9590 - val_loss: 2.9670 - val_accuracy: 0.5782
# Epoch 42/50
# 219/219 [==============================] - 2s 11ms/step - loss: 0.1458 - accuracy: 0.9541 - val_loss: 3.3886 - val_accuracy: 0.5652
# Epoch 43/50
# 219/219 [==============================] - 2s 11ms/step - loss: 0.1871 - accuracy: 0.9450 - val_loss: 3.2571 - val_accuracy: 0.5589
# Epoch 44/50
# 219/219 [==============================] - 2s 11ms/step - loss: 0.1380 - accuracy: 0.9548 - val_loss: 2.9911 - val_accuracy: 0.5772
# Epoch 45/50
# 219/219 [==============================] - 2s 11ms/step - loss: 0.1042 - accuracy: 0.9684 - val_loss: 2.9329 - val_accuracy: 0.6005
# Epoch 46/50
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0912 - accuracy: 0.9710 - val_loss: 3.0561 - val_accuracy: 0.5812
# Epoch 47/50
# 219/219 [==============================] - 3s 12ms/step - loss: 0.1152 - accuracy: 0.9653 - val_loss: 3.1259 - val_accuracy: 0.5725
# Epoch 48/50
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0602 - accuracy: 0.9820 - val_loss: 2.9481 - val_accuracy: 0.6029
# Epoch 49/50
# 219/219 [==============================] - 3s 12ms/step - loss: 0.0155 - accuracy: 0.9959 - val_loss: 2.8835 - val_accuracy: 0.6052
# Epoch 50/50
# 219/219 [==============================] - 2s 10ms/step - loss: 0.0084 - accuracy: 0.9983 - val_loss: 2.7939 - val_accuracy: 0.6165
